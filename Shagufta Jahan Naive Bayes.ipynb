# %% [markdown]
# # Prepare a classification model using Naive Bayes for salary data

# %%
#Importing the libraries
import numpy as np
from sklearn.model_selection import train_test_split as tts
import matplotlib.pyplot as plt
import pandas as pd

# %%
#load salary train data set
train=pd.read_csv("SalaryData_Train.csv")

# %%
#load salary test data set
test=pd.read_csv("SalaryData_Test.csv")

# %%
train
# Out:
#        age          workclass    education  educationno        maritalstatus  \
# 0       39          State-gov    Bachelors           13        Never-married
# 1       50   Self-emp-not-inc    Bachelors           13   Married-civ-spouse
# 2       38            Private      HS-grad            9             Divorced
# 3       53            Private         11th            7   Married-civ-spouse
# 4       28            Private    Bachelors           13   Married-civ-spouse
# ...    ...                ...          ...          ...                  ...
# 30156   27            Private   Assoc-acdm           12   Married-civ-spouse
# 30157   40            Private      HS-grad            9   Married-civ-spouse
# 30158   58            Private      HS-grad            9              Widowed
# 30159   22            Private      HS-grad            9        Never-married
# 30160   52       Self-emp-inc      HS-grad            9   Married-civ-spouse
#
# ...

# %%
test
# Out:
#        age      workclass      education  educationno        maritalstatus  \
# 0       25        Private           11th            7        Never-married
# 1       38        Private        HS-grad            9   Married-civ-spouse
# 2       28      Local-gov     Assoc-acdm           12   Married-civ-spouse
# 3       44        Private   Some-college           10   Married-civ-spouse
# 4       34        Private           10th            6        Never-married
# ...    ...            ...            ...          ...                  ...
# 15055   33        Private      Bachelors           13        Never-married
# 15056   39        Private      Bachelors           13             Divorced
# 15057   38        Private      Bachelors           13   Married-civ-spouse
# 15058   44        Private      Bachelors           13             Divorced
# 15059   35   Self-emp-inc      Bachelors           13   Married-civ-spouse
#
# ...

# %%
train.columns
# Out:
# Index(['age', 'workclass', 'education', 'educationno', 'maritalstatus',
#        'occupation', 'relationship', 'race', 'sex', 'capitalgain',
#        'capitalloss', 'hoursperweek', 'native', 'Salary'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['age', 'workclass', 'education', 'educationno', 'maritalstatus',
#        'occupation', 'relationship', 'race', 'sex', 'capitalgain',
#        'capitalloss', 'hoursperweek', 'native', 'Salary'],
#       dtype='object')

# %%
string_columns
# Out:
# ['workclass',
#  'education',
#  'maritalstatus',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'native']

# %%
#enoding using label encoder
from sklearn import preprocessing
label_encoder=preprocessing.LabelEncoder()
for i in string_columns:
    train[i]=label_encoder.fit_transform(train[i])
    test[i]=label_encoder.fit_transform(test[i])

# %%
train
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 30156   27          2          7           12              2          12
# 30157   40          2         11            9              2           6
# 30158   58          2         11            9              6           0
# 30159   22          2         11            9              4           0
# 30160   52          3         11            9              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %%
test
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       25          2          1            7              4           6
# 1       38          2         11            9              2           4
# 2       28          1          7           12              2          10
# 3       44          2         15           10              2           6
# 4       34          2          0            6              4           7
# ...    ...        ...        ...          ...            ...         ...
# 15055   33          2          9           13              4           9
# 15056   39          2          9           13              0           9
# 15057   38          2          9           13              2           9
# 15058   44          2          9           13              0           0
# 15059   35          3          9           13              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  \
# ...

# %%
col_names=list(train.columns)

# %%
col_names
# Out:
# ['age',
#  'workclass',
#  'education',
#  'educationno',
#  'maritalstatus',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'capitalgain',
#  'capitalloss',
#  'hoursperweek',
#  'native',
#  'Salary']

# %%
train_X=train[col_names[0:13]]
train_Y=train[col_names[13]]

# %%
#independent variables
train_X
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       39          5          9           13              4           0
# 1       50          4          9           13              2           3
# 2       38          2         11            9              0           5
# 3       53          2          1            7              2           5
# 4       28          2          9           13              2           9
# ...    ...        ...        ...          ...            ...         ...
# 30156   27          2          7           12              2          12
# 30157   40          2         11            9              2           6
# 30158   58          2         11            9              6           0
# 30159   22          2         11            9              4           0
# 30160   52          3         11            9              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  native
# ...

# %%
#dependent variable
train_Y
# Out:
# 0         <=50K
# 1         <=50K
# 2         <=50K
# 3         <=50K
# 4         <=50K
#           ...
# 30156     <=50K
# 30157      >50K
# 30158     <=50K
# 30159     <=50K
# 30160      >50K
# Name: Salary, Length: 30161, dtype: object

# %%
test_x=test[col_names[0:13]]
test_y=test[col_names[13]]

# %%
test_x
# Out:
#        age  workclass  education  educationno  maritalstatus  occupation  \
# 0       25          2          1            7              4           6
# 1       38          2         11            9              2           4
# 2       28          1          7           12              2          10
# 3       44          2         15           10              2           6
# 4       34          2          0            6              4           7
# ...    ...        ...        ...          ...            ...         ...
# 15055   33          2          9           13              4           9
# 15056   39          2          9           13              0           9
# 15057   38          2          9           13              2           9
# 15058   44          2          9           13              0           0
# 15059   35          3          9           13              2           3
#
#        relationship  race  sex  capitalgain  capitalloss  hoursperweek  native
# ...

# %%
test_y
# Out:
# 0         <=50K
# 1         <=50K
# 2          >50K
# 3          >50K
# 4         <=50K
#           ...
# 15055     <=50K
# 15056     <=50K
# 15057     <=50K
# 15058     <=50K
# 15059      >50K
# Name: Salary, Length: 15060, dtype: object

# %%
from sklearn.naive_bayes import MultinomialNB  
from sklearn.naive_bayes import GaussianNB

# %% [markdown]
# # Gaussian Naive Bayes

# %%
# training the model on training set
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(train_X,train_Y)
# Out:
# GaussianNB()

# %%
y_pred = gnb.predict(train_X)
y_pred
# Out:
# array([' <=50K', ' <=50K', ' <=50K', ..., ' <=50K', ' <=50K', ' >50K'],
#       dtype='<U6')

# %%
from sklearn import metrics
print("Gaussian Naive Bayes model accuracy(in %):", metrics.accuracy_score(train_Y, y_pred))
print("Gaussian Naive Bayes model accuracy(in %):", metrics.accuracy_score(train_Y, y_pred)*100)
# Out:
# Gaussian Naive Bayes model accuracy(in %): 0.7953317197705646
# Gaussian Naive Bayes model accuracy(in %): 79.53317197705645

# %% [markdown]
# # Gaussian Naive Bayes accuracy of train data set is 79.53%

# %%
# making predictions on the testing set
y_pred = gnb.predict(test_x)

# %%
y_pred
# Out:
# array([' <=50K', ' <=50K', ' <=50K', ..., ' <=50K', ' >50K', ' <=50K'],
#       dtype='<U6')

# %%
# comparing actual response values (y_test) with predicted response values (y_pred)
from sklearn import metrics
print("Gaussian Naive Bayes model accuracy(in %):", metrics.accuracy_score(test_y, y_pred)*100)
# Out:
# Gaussian Naive Bayes model accuracy(in %): 79.46879150066401

# %% [markdown]
# # Gaussian Naive Bayes accuracy of test data set is 79.46%

# %% [markdown]
# #  Multinomial Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB
Mmodel=MultinomialNB()

# %%
train_pred_multi=Mmodel.fit(train_X,train_Y).predict(train_X)
test_pred_multi=Mmodel.fit(train_X,train_Y).predict(test_x)

# %%
train_acc_multi=np.mean(train_pred_multi==train_Y)
test_acc_multi=np.mean(test_pred_multi==test_y)

# %%
train_acc_multi
# Out:
# 0.7729186698053778

# %% [markdown]
# # Multinomial Naive Bayes accuracy of train data set is 77.29%

# %%
test_acc_multi
# Out:
# 0.7749667994687915

# %% [markdown]
# # Multinomial Naive Bayes accuracy of test data set is 77.49%
